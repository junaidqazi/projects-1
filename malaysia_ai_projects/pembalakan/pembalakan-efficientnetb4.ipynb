# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
from efficientnet.tfkeras import EfficientNetB4
from efficientnet.tfkeras import center_crop_and_resize, preprocess_input
from tensorflow.keras.losses import binary_crossentropy
import tensorflow as tf
import numpy as np
import utils_tf1
from glob import glob
import cv2

# %%
from tensorflow.keras.layers import concatenate

def convolution_block(x, filters, size, strides=(1,1), padding='same', activation=True):
    x = tf.keras.layers.Conv2D(filters, size, strides=strides, padding=padding)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    if activation == True:
        x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
    return x

def residual_block(blockInput, num_filters=16):
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(blockInput)
    x = tf.keras.layers.BatchNormalization()(x)
    blockInput = tf.keras.layers.BatchNormalization()(blockInput)
    x = convolution_block(x, num_filters, (3,3) )
    x = convolution_block(x, num_filters, (3,3), activation=False)
    x = tf.math.add(x, blockInput)
    return x

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = tf.keras.layers.Flatten()(y_true)
    y_pred_f = tf.keras.layers.Flatten()(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * tf.reduce_sum(intersection) + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)
    return 1. - score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

class Model:
    def __init__(self, img_size = 256, dropout_rate=0.1):
        self.X = tf.placeholder(tf.float32, (None, img_size, img_size, 3))
        self.Y = tf.placeholder(tf.float32, (None, img_size, img_size, 1))
        backbone = EfficientNetB4(weights='imagenet',
                            include_top=False,
                          input_tensor=self.X)
        self.efficientnet = backbone
        start_neurons = 16
        
        # [B, 16, 16, 160]
        conv4 = backbone.layers[314].output
        conv4 = tf.keras.layers.LeakyReLU(alpha=0.1)(conv4)
        pool4 = tf.keras.layers.MaxPooling2D((2, 2))(conv4)
        pool4 = tf.keras.layers.Dropout(dropout_rate)(pool4)
        # [B, 8, 8, 160]
        
        # [B, 8, 8, 512]
        convm = tf.keras.layers.Conv2D(start_neurons * 32, (3, 3), activation=None, padding="same")(pool4)
        convm = residual_block(convm,start_neurons * 32)
        convm = residual_block(convm,start_neurons * 32)
        # [B, 8, 8, 512]
        convm = tf.keras.layers.LeakyReLU(alpha=0.1)(convm)
        
        # [B, 16, 16, 256]
        deconv4 = tf.keras.layers.Conv2DTranspose(start_neurons * 16, (3, 3), strides=(2, 2), padding="same")(convm)
        uconv4 = concatenate([deconv4, conv4])
        # [B, 16, 16, 416]
        uconv4 = tf.keras.layers.Dropout(dropout_rate)(uconv4)
        
        # [B, 16, 16, 256]
        uconv4 = tf.keras.layers.Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(uconv4)
        uconv4 = residual_block(uconv4,start_neurons * 16)
        uconv4 = residual_block(uconv4,start_neurons * 16)
        # [B, 16, 16, 256]
        uconv4 = tf.keras.layers.LeakyReLU(alpha=0.1)(uconv4)
        
        # [B, 32, 32, 128]
        deconv3 = tf.keras.layers.Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(uconv4)
        # [B, 32, 32, 56]
        conv3 = backbone.layers[138].output
        # [B, 32, 32, 184]
        uconv3 = concatenate([deconv3, conv3])    
        uconv3 = tf.keras.layers.Dropout(dropout_rate)(uconv3)
        
        # [B, 32, 32, 128]
        uconv3 = tf.keras.layers.Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv3)
        uconv3 = residual_block(uconv3,start_neurons * 8)
        uconv3 = residual_block(uconv3,start_neurons * 8)
        # [B, 32, 32, 128]
        uconv3 = tf.keras.layers.LeakyReLU(alpha=0.1)(uconv3)
        
        # [B, 64, 64, 64]
        deconv2 = tf.keras.layers.Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv3)
        # [B, 64, 64, 32]
        conv2 = backbone.layers[65].output
        # [B, 64, 64, 96]
        uconv2 = concatenate([deconv2, conv2])
        uconv2 = tf.keras.layers.Dropout(0.1)(uconv2)
        
        # [B, 64, 64, 64]
        uconv2 = tf.keras.layers.Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv2)
        uconv2 = residual_block(uconv2,start_neurons * 4)
        uconv2 = residual_block(uconv2,start_neurons * 4)
        uconv2 = tf.keras.layers.LeakyReLU(alpha=0.1)(uconv2)
        
        # [B, 128, 128, 32]
        deconv1 = tf.keras.layers.Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv2)
        # [B, 128, 128, 24]
        conv1 = backbone.layers[22].output
        # [B, 128, 128, 66]
        uconv1 = concatenate([deconv1, conv1])
        uconv1 = tf.keras.layers.Dropout(0.1)(uconv1)
        
        # [B, 128, 128, 32]
        uconv1 = tf.keras.layers.Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv1)
        uconv1 = residual_block(uconv1,start_neurons * 2)
        uconv1 = residual_block(uconv1,start_neurons * 2)
        uconv1 = tf.keras.layers.LeakyReLU(alpha=0.1)(uconv1)
        
        # [B, 256, 256, 16]
        uconv0 = tf.keras.layers.Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv1)   
        uconv0 = tf.keras.layers.Dropout(0.1)(uconv0)
        uconv0 = tf.keras.layers.Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv0)
        uconv0 = residual_block(uconv0,start_neurons * 1)
        uconv0 = residual_block(uconv0,start_neurons * 1)
        uconv0 = tf.keras.layers.LeakyReLU(alpha=0.1)(uconv0)

        uconv0 = tf.keras.layers.Dropout(dropout_rate/2)(uconv0)
        self.logits = tf.keras.layers.Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv0)

# %%
tf.compat.v1.reset_default_graph()
model = Model()
# Out:
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/util/deprecation.py:507: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
loss = tf.reduce_mean(bce_dice_loss(model.Y, model.logits))
loss
# Out:
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# <tf.Tensor 'Mean_1:0' shape=() dtype=float32>

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
var_list = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)
assignment_map, initialized_variable_names = utils_tf1.get_assignment_map_from_checkpoint(var_list, 
                                                                                          'out/model.ckpt')
# Out:
# WARNING:tensorflow:From /home/husein/malaya/projects/malaysia_ai_projects/forestnet/utils_tf1.py:141: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:  name = stem_conv/kernel:0, shape = (3, 3, 3, 48), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = stem_bn/gamma:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = stem_bn/beta:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = stem_bn/moving_mean:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = stem_bn/moving_variance:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_dwconv/depthwise_kernel:0, shape = (3, 3, 48, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_bn/gamma:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_bn/beta:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_bn/moving_mean:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_bn/moving_variance:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_se_reduce/kernel:0, shape = (1, 1, 48, 12), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_se_reduce/bias:0, shape = (12,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_se_expand/kernel:0, shape = (1, 1, 12, 48), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_se_expand/bias:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_project_conv/kernel:0, shape = (1, 1, 48, 24), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_project_bn/gamma:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_project_bn/beta:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_project_bn/moving_mean:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_project_bn/moving_variance:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_dwconv/depthwise_kernel:0, shape = (3, 3, 24, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_bn/gamma:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_bn/beta:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_bn/moving_mean:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_bn/moving_variance:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_se_reduce/kernel:0, shape = (1, 1, 24, 6), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_se_reduce/bias:0, shape = (6,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_se_expand/kernel:0, shape = (1, 1, 6, 24), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_se_expand/bias:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_project_conv/kernel:0, shape = (1, 1, 24, 24), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_project_bn/gamma:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_project_bn/beta:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_project_bn/moving_mean:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_project_bn/moving_variance:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_expand_conv/kernel:0, shape = (1, 1, 24, 144), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_expand_bn/gamma:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_expand_bn/beta:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_expand_bn/moving_mean:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_expand_bn/moving_variance:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_dwconv/depthwise_kernel:0, shape = (3, 3, 144, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_bn/gamma:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_bn/beta:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_bn/moving_mean:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_bn/moving_variance:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_se_reduce/kernel:0, shape = (1, 1, 144, 6), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_se_reduce/bias:0, shape = (6,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_se_expand/kernel:0, shape = (1, 1, 6, 144), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_se_expand/bias:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_project_conv/kernel:0, shape = (1, 1, 144, 32), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_project_bn/gamma:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_project_bn/beta:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_project_bn/moving_mean:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_project_bn/moving_variance:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_expand_conv/kernel:0, shape = (1, 1, 32, 192), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_expand_bn/gamma:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_expand_bn/beta:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_expand_bn/moving_mean:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_expand_bn/moving_variance:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_dwconv/depthwise_kernel:0, shape = (3, 3, 192, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_bn/gamma:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_bn/beta:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_bn/moving_mean:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_bn/moving_variance:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_se_reduce/kernel:0, shape = (1, 1, 192, 8), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_se_reduce/bias:0, shape = (8,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_se_expand/kernel:0, shape = (1, 1, 8, 192), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_se_expand/bias:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_project_conv/kernel:0, shape = (1, 1, 192, 32), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_project_bn/gamma:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_project_bn/beta:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_project_bn/moving_mean:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_project_bn/moving_variance:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_expand_conv/kernel:0, shape = (1, 1, 32, 192), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_expand_bn/gamma:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_expand_bn/beta:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_expand_bn/moving_mean:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_expand_bn/moving_variance:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_dwconv/depthwise_kernel:0, shape = (3, 3, 192, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_bn/gamma:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_bn/beta:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_bn/moving_mean:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_bn/moving_variance:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_se_reduce/kernel:0, shape = (1, 1, 192, 8), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_se_reduce/bias:0, shape = (8,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_se_expand/kernel:0, shape = (1, 1, 8, 192), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_se_expand/bias:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_project_conv/kernel:0, shape = (1, 1, 192, 32), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_project_bn/gamma:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_project_bn/beta:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_project_bn/moving_mean:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_project_bn/moving_variance:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_expand_conv/kernel:0, shape = (1, 1, 32, 192), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_expand_bn/gamma:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_expand_bn/beta:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_expand_bn/moving_mean:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_expand_bn/moving_variance:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_dwconv/depthwise_kernel:0, shape = (3, 3, 192, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_bn/gamma:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_bn/beta:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_bn/moving_mean:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_bn/moving_variance:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_se_reduce/kernel:0, shape = (1, 1, 192, 8), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_se_reduce/bias:0, shape = (8,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_se_expand/kernel:0, shape = (1, 1, 8, 192), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_se_expand/bias:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_project_conv/kernel:0, shape = (1, 1, 192, 32), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_project_bn/gamma:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_project_bn/beta:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_project_bn/moving_mean:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2d_project_bn/moving_variance:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_expand_conv/kernel:0, shape = (1, 1, 32, 192), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_expand_bn/gamma:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_expand_bn/beta:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_expand_bn/moving_mean:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_expand_bn/moving_variance:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_dwconv/depthwise_kernel:0, shape = (5, 5, 192, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_bn/gamma:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_bn/beta:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_bn/moving_mean:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_bn/moving_variance:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_se_reduce/kernel:0, shape = (1, 1, 192, 8), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_se_reduce/bias:0, shape = (8,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_se_expand/kernel:0, shape = (1, 1, 8, 192), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_se_expand/bias:0, shape = (192,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_project_conv/kernel:0, shape = (1, 1, 192, 56), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_project_bn/gamma:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_project_bn/beta:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_project_bn/moving_mean:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_project_bn/moving_variance:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_expand_conv/kernel:0, shape = (1, 1, 56, 336), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_expand_bn/gamma:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_expand_bn/beta:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_expand_bn/moving_mean:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_expand_bn/moving_variance:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_dwconv/depthwise_kernel:0, shape = (5, 5, 336, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_bn/gamma:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_bn/beta:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_bn/moving_mean:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_bn/moving_variance:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_se_reduce/kernel:0, shape = (1, 1, 336, 14), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_se_reduce/bias:0, shape = (14,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_se_expand/kernel:0, shape = (1, 1, 14, 336), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_se_expand/bias:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_project_conv/kernel:0, shape = (1, 1, 336, 56), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_project_bn/gamma:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_project_bn/beta:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_project_bn/moving_mean:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_project_bn/moving_variance:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_expand_conv/kernel:0, shape = (1, 1, 56, 336), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_expand_bn/gamma:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_expand_bn/beta:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_expand_bn/moving_mean:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_expand_bn/moving_variance:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_dwconv/depthwise_kernel:0, shape = (5, 5, 336, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_bn/gamma:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_bn/beta:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_bn/moving_mean:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_bn/moving_variance:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_se_reduce/kernel:0, shape = (1, 1, 336, 14), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_se_reduce/bias:0, shape = (14,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_se_expand/kernel:0, shape = (1, 1, 14, 336), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_se_expand/bias:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_project_conv/kernel:0, shape = (1, 1, 336, 56), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_project_bn/gamma:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_project_bn/beta:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_project_bn/moving_mean:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_project_bn/moving_variance:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_expand_conv/kernel:0, shape = (1, 1, 56, 336), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_expand_bn/gamma:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_expand_bn/beta:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_expand_bn/moving_mean:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_expand_bn/moving_variance:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_dwconv/depthwise_kernel:0, shape = (5, 5, 336, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_bn/gamma:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_bn/beta:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_bn/moving_mean:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_bn/moving_variance:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_se_reduce/kernel:0, shape = (1, 1, 336, 14), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_se_reduce/bias:0, shape = (14,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_se_expand/kernel:0, shape = (1, 1, 14, 336), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_se_expand/bias:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_project_conv/kernel:0, shape = (1, 1, 336, 56), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_project_bn/gamma:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_project_bn/beta:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_project_bn/moving_mean:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3d_project_bn/moving_variance:0, shape = (56,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_expand_conv/kernel:0, shape = (1, 1, 56, 336), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_expand_bn/gamma:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_expand_bn/beta:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_expand_bn/moving_mean:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_expand_bn/moving_variance:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_dwconv/depthwise_kernel:0, shape = (3, 3, 336, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_bn/gamma:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_bn/beta:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_bn/moving_mean:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_bn/moving_variance:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_se_reduce/kernel:0, shape = (1, 1, 336, 14), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_se_reduce/bias:0, shape = (14,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_se_expand/kernel:0, shape = (1, 1, 14, 336), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_se_expand/bias:0, shape = (336,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_project_conv/kernel:0, shape = (1, 1, 336, 112), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_project_bn/gamma:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_project_bn/beta:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_project_bn/moving_mean:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_project_bn/moving_variance:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_expand_conv/kernel:0, shape = (1, 1, 112, 672), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_expand_bn/gamma:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_expand_bn/beta:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_expand_bn/moving_mean:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_expand_bn/moving_variance:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_dwconv/depthwise_kernel:0, shape = (3, 3, 672, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_bn/gamma:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_bn/beta:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_bn/moving_mean:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_bn/moving_variance:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_se_reduce/kernel:0, shape = (1, 1, 672, 28), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_se_reduce/bias:0, shape = (28,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_se_expand/kernel:0, shape = (1, 1, 28, 672), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_se_expand/bias:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_project_conv/kernel:0, shape = (1, 1, 672, 112), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_project_bn/gamma:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_project_bn/beta:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_project_bn/moving_mean:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_project_bn/moving_variance:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_expand_conv/kernel:0, shape = (1, 1, 112, 672), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_expand_bn/gamma:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_expand_bn/beta:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_expand_bn/moving_mean:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_expand_bn/moving_variance:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_dwconv/depthwise_kernel:0, shape = (3, 3, 672, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_bn/gamma:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_bn/beta:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_bn/moving_mean:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_bn/moving_variance:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_se_reduce/kernel:0, shape = (1, 1, 672, 28), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_se_reduce/bias:0, shape = (28,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_se_expand/kernel:0, shape = (1, 1, 28, 672), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_se_expand/bias:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_project_conv/kernel:0, shape = (1, 1, 672, 112), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_project_bn/gamma:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_project_bn/beta:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_project_bn/moving_mean:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_project_bn/moving_variance:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_expand_conv/kernel:0, shape = (1, 1, 112, 672), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_expand_bn/gamma:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_expand_bn/beta:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_expand_bn/moving_mean:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_expand_bn/moving_variance:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_dwconv/depthwise_kernel:0, shape = (3, 3, 672, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_bn/gamma:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_bn/beta:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_bn/moving_mean:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_bn/moving_variance:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_se_reduce/kernel:0, shape = (1, 1, 672, 28), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_se_reduce/bias:0, shape = (28,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_se_expand/kernel:0, shape = (1, 1, 28, 672), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_se_expand/bias:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_project_conv/kernel:0, shape = (1, 1, 672, 112), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_project_bn/gamma:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_project_bn/beta:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_project_bn/moving_mean:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_project_bn/moving_variance:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_expand_conv/kernel:0, shape = (1, 1, 112, 672), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_expand_bn/gamma:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_expand_bn/beta:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_expand_bn/moving_mean:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_expand_bn/moving_variance:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_dwconv/depthwise_kernel:0, shape = (3, 3, 672, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_bn/gamma:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_bn/beta:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_bn/moving_mean:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_bn/moving_variance:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_se_reduce/kernel:0, shape = (1, 1, 672, 28), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_se_reduce/bias:0, shape = (28,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_se_expand/kernel:0, shape = (1, 1, 28, 672), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_se_expand/bias:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_project_conv/kernel:0, shape = (1, 1, 672, 112), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_project_bn/gamma:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_project_bn/beta:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_project_bn/moving_mean:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4e_project_bn/moving_variance:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_expand_conv/kernel:0, shape = (1, 1, 112, 672), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_expand_bn/gamma:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_expand_bn/beta:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_expand_bn/moving_mean:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_expand_bn/moving_variance:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_dwconv/depthwise_kernel:0, shape = (3, 3, 672, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_bn/gamma:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_bn/beta:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_bn/moving_mean:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_bn/moving_variance:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_se_reduce/kernel:0, shape = (1, 1, 672, 28), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_se_reduce/bias:0, shape = (28,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_se_expand/kernel:0, shape = (1, 1, 28, 672), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_se_expand/bias:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_project_conv/kernel:0, shape = (1, 1, 672, 112), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_project_bn/gamma:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_project_bn/beta:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_project_bn/moving_mean:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4f_project_bn/moving_variance:0, shape = (112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_expand_conv/kernel:0, shape = (1, 1, 112, 672), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_expand_bn/gamma:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_expand_bn/beta:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_expand_bn/moving_mean:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_expand_bn/moving_variance:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_dwconv/depthwise_kernel:0, shape = (5, 5, 672, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_bn/gamma:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_bn/beta:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_bn/moving_mean:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_bn/moving_variance:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_se_reduce/kernel:0, shape = (1, 1, 672, 28), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_se_reduce/bias:0, shape = (28,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_se_expand/kernel:0, shape = (1, 1, 28, 672), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_se_expand/bias:0, shape = (672,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_project_conv/kernel:0, shape = (1, 1, 672, 160), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_project_bn/gamma:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_project_bn/beta:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_project_bn/moving_mean:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_project_bn/moving_variance:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_expand_conv/kernel:0, shape = (1, 1, 160, 960), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_expand_bn/gamma:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_expand_bn/beta:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_expand_bn/moving_mean:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_expand_bn/moving_variance:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_dwconv/depthwise_kernel:0, shape = (5, 5, 960, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_bn/gamma:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_bn/beta:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_bn/moving_mean:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_bn/moving_variance:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_se_reduce/kernel:0, shape = (1, 1, 960, 40), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_se_reduce/bias:0, shape = (40,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_se_expand/kernel:0, shape = (1, 1, 40, 960), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_se_expand/bias:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_project_conv/kernel:0, shape = (1, 1, 960, 160), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_project_bn/gamma:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_project_bn/beta:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_project_bn/moving_mean:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_project_bn/moving_variance:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_expand_conv/kernel:0, shape = (1, 1, 160, 960), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_expand_bn/gamma:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_expand_bn/beta:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_expand_bn/moving_mean:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_expand_bn/moving_variance:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_dwconv/depthwise_kernel:0, shape = (5, 5, 960, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_bn/gamma:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_bn/beta:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_bn/moving_mean:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_bn/moving_variance:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_se_reduce/kernel:0, shape = (1, 1, 960, 40), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_se_reduce/bias:0, shape = (40,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_se_expand/kernel:0, shape = (1, 1, 40, 960), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_se_expand/bias:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_project_conv/kernel:0, shape = (1, 1, 960, 160), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_project_bn/gamma:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_project_bn/beta:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_project_bn/moving_mean:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_project_bn/moving_variance:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_expand_conv/kernel:0, shape = (1, 1, 160, 960), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_expand_bn/gamma:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_expand_bn/beta:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_expand_bn/moving_mean:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_expand_bn/moving_variance:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_dwconv/depthwise_kernel:0, shape = (5, 5, 960, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_bn/gamma:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_bn/beta:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_bn/moving_mean:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_bn/moving_variance:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_se_reduce/kernel:0, shape = (1, 1, 960, 40), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_se_reduce/bias:0, shape = (40,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_se_expand/kernel:0, shape = (1, 1, 40, 960), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_se_expand/bias:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_project_conv/kernel:0, shape = (1, 1, 960, 160), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_project_bn/gamma:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_project_bn/beta:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_project_bn/moving_mean:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_project_bn/moving_variance:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_expand_conv/kernel:0, shape = (1, 1, 160, 960), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_expand_bn/gamma:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_expand_bn/beta:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_expand_bn/moving_mean:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_expand_bn/moving_variance:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_dwconv/depthwise_kernel:0, shape = (5, 5, 960, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_bn/gamma:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_bn/beta:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_bn/moving_mean:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_bn/moving_variance:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_se_reduce/kernel:0, shape = (1, 1, 960, 40), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_se_reduce/bias:0, shape = (40,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_se_expand/kernel:0, shape = (1, 1, 40, 960), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_se_expand/bias:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_project_conv/kernel:0, shape = (1, 1, 960, 160), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_project_bn/gamma:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_project_bn/beta:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_project_bn/moving_mean:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5e_project_bn/moving_variance:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_expand_conv/kernel:0, shape = (1, 1, 160, 960), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_expand_bn/gamma:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_expand_bn/beta:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_expand_bn/moving_mean:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_expand_bn/moving_variance:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_dwconv/depthwise_kernel:0, shape = (5, 5, 960, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_bn/gamma:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_bn/beta:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_bn/moving_mean:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_bn/moving_variance:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_se_reduce/kernel:0, shape = (1, 1, 960, 40), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_se_reduce/bias:0, shape = (40,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_se_expand/kernel:0, shape = (1, 1, 40, 960), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_se_expand/bias:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_project_conv/kernel:0, shape = (1, 1, 960, 160), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_project_bn/gamma:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_project_bn/beta:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_project_bn/moving_mean:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5f_project_bn/moving_variance:0, shape = (160,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_expand_conv/kernel:0, shape = (1, 1, 160, 960), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_expand_bn/gamma:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_expand_bn/beta:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_expand_bn/moving_mean:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_expand_bn/moving_variance:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_dwconv/depthwise_kernel:0, shape = (5, 5, 960, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_bn/gamma:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_bn/beta:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_bn/moving_mean:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_bn/moving_variance:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_se_reduce/kernel:0, shape = (1, 1, 960, 40), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_se_reduce/bias:0, shape = (40,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_se_expand/kernel:0, shape = (1, 1, 40, 960), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_se_expand/bias:0, shape = (960,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_project_conv/kernel:0, shape = (1, 1, 960, 272), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_project_bn/gamma:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_project_bn/beta:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_project_bn/moving_mean:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_project_bn/moving_variance:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_expand_conv/kernel:0, shape = (1, 1, 272, 1632), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_expand_bn/gamma:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_expand_bn/beta:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_expand_bn/moving_mean:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_expand_bn/moving_variance:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_dwconv/depthwise_kernel:0, shape = (5, 5, 1632, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_bn/gamma:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_bn/beta:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_bn/moving_mean:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_bn/moving_variance:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_se_reduce/kernel:0, shape = (1, 1, 1632, 68), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_se_reduce/bias:0, shape = (68,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_se_expand/kernel:0, shape = (1, 1, 68, 1632), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_se_expand/bias:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_project_conv/kernel:0, shape = (1, 1, 1632, 272), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_project_bn/gamma:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_project_bn/beta:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_project_bn/moving_mean:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_project_bn/moving_variance:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_expand_conv/kernel:0, shape = (1, 1, 272, 1632), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_expand_bn/gamma:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_expand_bn/beta:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_expand_bn/moving_mean:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_expand_bn/moving_variance:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_dwconv/depthwise_kernel:0, shape = (5, 5, 1632, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_bn/gamma:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_bn/beta:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_bn/moving_mean:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_bn/moving_variance:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_se_reduce/kernel:0, shape = (1, 1, 1632, 68), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_se_reduce/bias:0, shape = (68,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_se_expand/kernel:0, shape = (1, 1, 68, 1632), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_se_expand/bias:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_project_conv/kernel:0, shape = (1, 1, 1632, 272), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_project_bn/gamma:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_project_bn/beta:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_project_bn/moving_mean:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_project_bn/moving_variance:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_expand_conv/kernel:0, shape = (1, 1, 272, 1632), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_expand_bn/gamma:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_expand_bn/beta:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_expand_bn/moving_mean:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_expand_bn/moving_variance:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_dwconv/depthwise_kernel:0, shape = (5, 5, 1632, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_bn/gamma:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_bn/beta:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_bn/moving_mean:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_bn/moving_variance:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_se_reduce/kernel:0, shape = (1, 1, 1632, 68), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_se_reduce/bias:0, shape = (68,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_se_expand/kernel:0, shape = (1, 1, 68, 1632), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_se_expand/bias:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_project_conv/kernel:0, shape = (1, 1, 1632, 272), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_project_bn/gamma:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_project_bn/beta:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_project_bn/moving_mean:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_project_bn/moving_variance:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_expand_conv/kernel:0, shape = (1, 1, 272, 1632), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_expand_bn/gamma:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_expand_bn/beta:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_expand_bn/moving_mean:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_expand_bn/moving_variance:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_dwconv/depthwise_kernel:0, shape = (5, 5, 1632, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_bn/gamma:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_bn/beta:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_bn/moving_mean:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_bn/moving_variance:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_se_reduce/kernel:0, shape = (1, 1, 1632, 68), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_se_reduce/bias:0, shape = (68,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_se_expand/kernel:0, shape = (1, 1, 68, 1632), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_se_expand/bias:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_project_conv/kernel:0, shape = (1, 1, 1632, 272), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_project_bn/gamma:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_project_bn/beta:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_project_bn/moving_mean:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_project_bn/moving_variance:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_expand_conv/kernel:0, shape = (1, 1, 272, 1632), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_expand_bn/gamma:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_expand_bn/beta:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_expand_bn/moving_mean:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_expand_bn/moving_variance:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_dwconv/depthwise_kernel:0, shape = (5, 5, 1632, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_bn/gamma:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_bn/beta:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_bn/moving_mean:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_bn/moving_variance:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_se_reduce/kernel:0, shape = (1, 1, 1632, 68), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_se_reduce/bias:0, shape = (68,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_se_expand/kernel:0, shape = (1, 1, 68, 1632), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_se_expand/bias:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_project_conv/kernel:0, shape = (1, 1, 1632, 272), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_project_bn/gamma:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_project_bn/beta:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_project_bn/moving_mean:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6f_project_bn/moving_variance:0, shape = (272,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6g_expand_conv/kernel:0, shape = (1, 1, 272, 1632), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6g_expand_bn/gamma:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6g_expand_bn/beta:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6g_expand_bn/moving_mean:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6g_expand_bn/moving_variance:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6g_dwconv/depthwise_kernel:0, shape = (5, 5, 1632, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6g_bn/gamma:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6g_bn/beta:0, shape = (1632,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6g_bn/moving_mean:0, shape = (1632,), *INIT_FROM_CKPT*
# ...
# INFO:tensorflow:  name = conv2d_transpose/bias:0, shape = (256,)
# INFO:tensorflow:  name = conv2d_5/kernel:0, shape = (3, 3, 416, 256)
# INFO:tensorflow:  name = conv2d_5/bias:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_8/gamma:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_8/beta:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_8/moving_mean:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_8/moving_variance:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_9/gamma:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_9/beta:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_9/moving_mean:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_9/moving_variance:0, shape = (256,)
# INFO:tensorflow:  name = conv2d_6/kernel:0, shape = (3, 3, 256, 256)
# INFO:tensorflow:  name = conv2d_6/bias:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_10/gamma:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_10/beta:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_10/moving_mean:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_10/moving_variance:0, shape = (256,)
# INFO:tensorflow:  name = conv2d_7/kernel:0, shape = (3, 3, 256, 256)
# INFO:tensorflow:  name = conv2d_7/bias:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_11/gamma:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_11/beta:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_11/moving_mean:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_11/moving_variance:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_12/gamma:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_12/beta:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_12/moving_mean:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_12/moving_variance:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_13/gamma:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_13/beta:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_13/moving_mean:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_13/moving_variance:0, shape = (256,)
# INFO:tensorflow:  name = conv2d_8/kernel:0, shape = (3, 3, 256, 256)
# INFO:tensorflow:  name = conv2d_8/bias:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_14/gamma:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_14/beta:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_14/moving_mean:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_14/moving_variance:0, shape = (256,)
# INFO:tensorflow:  name = conv2d_9/kernel:0, shape = (3, 3, 256, 256)
# INFO:tensorflow:  name = conv2d_9/bias:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_15/gamma:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_15/beta:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_15/moving_mean:0, shape = (256,)
# INFO:tensorflow:  name = batch_normalization_15/moving_variance:0, shape = (256,)
# INFO:tensorflow:  name = conv2d_transpose_1/kernel:0, shape = (3, 3, 128, 256)
# INFO:tensorflow:  name = conv2d_transpose_1/bias:0, shape = (128,)
# INFO:tensorflow:  name = conv2d_10/kernel:0, shape = (3, 3, 184, 128)
# INFO:tensorflow:  name = conv2d_10/bias:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_16/gamma:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_16/beta:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_16/moving_mean:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_16/moving_variance:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_17/gamma:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_17/beta:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_17/moving_mean:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_17/moving_variance:0, shape = (128,)
# INFO:tensorflow:  name = conv2d_11/kernel:0, shape = (3, 3, 128, 128)
# INFO:tensorflow:  name = conv2d_11/bias:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_18/gamma:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_18/beta:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_18/moving_mean:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_18/moving_variance:0, shape = (128,)
# INFO:tensorflow:  name = conv2d_12/kernel:0, shape = (3, 3, 128, 128)
# INFO:tensorflow:  name = conv2d_12/bias:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_19/gamma:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_19/beta:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_19/moving_mean:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_19/moving_variance:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_20/gamma:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_20/beta:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_20/moving_mean:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_20/moving_variance:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_21/gamma:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_21/beta:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_21/moving_mean:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_21/moving_variance:0, shape = (128,)
# INFO:tensorflow:  name = conv2d_13/kernel:0, shape = (3, 3, 128, 128)
# INFO:tensorflow:  name = conv2d_13/bias:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_22/gamma:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_22/beta:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_22/moving_mean:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_22/moving_variance:0, shape = (128,)
# INFO:tensorflow:  name = conv2d_14/kernel:0, shape = (3, 3, 128, 128)
# INFO:tensorflow:  name = conv2d_14/bias:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_23/gamma:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_23/beta:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_23/moving_mean:0, shape = (128,)
# INFO:tensorflow:  name = batch_normalization_23/moving_variance:0, shape = (128,)
# INFO:tensorflow:  name = conv2d_transpose_2/kernel:0, shape = (3, 3, 64, 128)
# INFO:tensorflow:  name = conv2d_transpose_2/bias:0, shape = (64,)
# INFO:tensorflow:  name = conv2d_15/kernel:0, shape = (3, 3, 96, 64)
# INFO:tensorflow:  name = conv2d_15/bias:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_24/gamma:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_24/beta:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_24/moving_mean:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_24/moving_variance:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_25/gamma:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_25/beta:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_25/moving_mean:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_25/moving_variance:0, shape = (64,)
# INFO:tensorflow:  name = conv2d_16/kernel:0, shape = (3, 3, 64, 64)
# INFO:tensorflow:  name = conv2d_16/bias:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_26/gamma:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_26/beta:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_26/moving_mean:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_26/moving_variance:0, shape = (64,)
# INFO:tensorflow:  name = conv2d_17/kernel:0, shape = (3, 3, 64, 64)
# INFO:tensorflow:  name = conv2d_17/bias:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_27/gamma:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_27/beta:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_27/moving_mean:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_27/moving_variance:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_28/gamma:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_28/beta:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_28/moving_mean:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_28/moving_variance:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_29/gamma:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_29/beta:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_29/moving_mean:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_29/moving_variance:0, shape = (64,)
# INFO:tensorflow:  name = conv2d_18/kernel:0, shape = (3, 3, 64, 64)
# INFO:tensorflow:  name = conv2d_18/bias:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_30/gamma:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_30/beta:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_30/moving_mean:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_30/moving_variance:0, shape = (64,)
# INFO:tensorflow:  name = conv2d_19/kernel:0, shape = (3, 3, 64, 64)
# INFO:tensorflow:  name = conv2d_19/bias:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_31/gamma:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_31/beta:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_31/moving_mean:0, shape = (64,)
# INFO:tensorflow:  name = batch_normalization_31/moving_variance:0, shape = (64,)
# INFO:tensorflow:  name = conv2d_transpose_3/kernel:0, shape = (3, 3, 32, 64)
# INFO:tensorflow:  name = conv2d_transpose_3/bias:0, shape = (32,)
# INFO:tensorflow:  name = conv2d_20/kernel:0, shape = (3, 3, 56, 32)
# INFO:tensorflow:  name = conv2d_20/bias:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_32/gamma:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_32/beta:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_32/moving_mean:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_32/moving_variance:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_33/gamma:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_33/beta:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_33/moving_mean:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_33/moving_variance:0, shape = (32,)
# INFO:tensorflow:  name = conv2d_21/kernel:0, shape = (3, 3, 32, 32)
# INFO:tensorflow:  name = conv2d_21/bias:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_34/gamma:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_34/beta:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_34/moving_mean:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_34/moving_variance:0, shape = (32,)
# INFO:tensorflow:  name = conv2d_22/kernel:0, shape = (3, 3, 32, 32)
# INFO:tensorflow:  name = conv2d_22/bias:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_35/gamma:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_35/beta:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_35/moving_mean:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_35/moving_variance:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_36/gamma:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_36/beta:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_36/moving_mean:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_36/moving_variance:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_37/gamma:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_37/beta:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_37/moving_mean:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_37/moving_variance:0, shape = (32,)
# INFO:tensorflow:  name = conv2d_23/kernel:0, shape = (3, 3, 32, 32)
# INFO:tensorflow:  name = conv2d_23/bias:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_38/gamma:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_38/beta:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_38/moving_mean:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_38/moving_variance:0, shape = (32,)
# INFO:tensorflow:  name = conv2d_24/kernel:0, shape = (3, 3, 32, 32)
# INFO:tensorflow:  name = conv2d_24/bias:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_39/gamma:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_39/beta:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_39/moving_mean:0, shape = (32,)
# INFO:tensorflow:  name = batch_normalization_39/moving_variance:0, shape = (32,)
# INFO:tensorflow:  name = conv2d_transpose_4/kernel:0, shape = (3, 3, 16, 32)
# INFO:tensorflow:  name = conv2d_transpose_4/bias:0, shape = (16,)
# INFO:tensorflow:  name = conv2d_25/kernel:0, shape = (3, 3, 16, 16)
# INFO:tensorflow:  name = conv2d_25/bias:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_40/gamma:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_40/beta:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_40/moving_mean:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_40/moving_variance:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_41/gamma:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_41/beta:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_41/moving_mean:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_41/moving_variance:0, shape = (16,)
# INFO:tensorflow:  name = conv2d_26/kernel:0, shape = (3, 3, 16, 16)
# INFO:tensorflow:  name = conv2d_26/bias:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_42/gamma:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_42/beta:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_42/moving_mean:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_42/moving_variance:0, shape = (16,)
# INFO:tensorflow:  name = conv2d_27/kernel:0, shape = (3, 3, 16, 16)
# INFO:tensorflow:  name = conv2d_27/bias:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_43/gamma:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_43/beta:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_43/moving_mean:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_43/moving_variance:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_44/gamma:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_44/beta:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_44/moving_mean:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_44/moving_variance:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_45/gamma:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_45/beta:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_45/moving_mean:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_45/moving_variance:0, shape = (16,)
# INFO:tensorflow:  name = conv2d_28/kernel:0, shape = (3, 3, 16, 16)
# INFO:tensorflow:  name = conv2d_28/bias:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_46/gamma:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_46/beta:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_46/moving_mean:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_46/moving_variance:0, shape = (16,)
# INFO:tensorflow:  name = conv2d_29/kernel:0, shape = (3, 3, 16, 16)
# INFO:tensorflow:  name = conv2d_29/bias:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_47/gamma:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_47/beta:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_47/moving_mean:0, shape = (16,)
# INFO:tensorflow:  name = batch_normalization_47/moving_variance:0, shape = (16,)
# INFO:tensorflow:  name = conv2d_30/kernel:0, shape = (1, 1, 16, 1)
# INFO:tensorflow:  name = conv2d_30/bias:0, shape = (1,)

# %%
saver = tf.train.Saver(var_list = assignment_map)
saver.restore(sess, 'out/model.ckpt')
# Out:
# INFO:tensorflow:Restoring parameters from out/model.ckpt

# %%
def _parse_image_function(example_proto):
    image_feature_description = {
        "image": tf.compat.v1.FixedLenFeature([], tf.string),
        "mask": tf.compat.v1.FixedLenFeature([], tf.string),
    }
    features = tf.compat.v1.parse_single_example(example_proto, features=image_feature_description)
    image = tf.image.decode_png(features['image'], channels = 3)
    image = tf.image.resize(image, [512, 512])
    image = tf.cast(image, tf.float32) / 255.0
    features['image'] = image
    mask = tf.io.decode_raw(features['mask'], out_type="float")
    mask = tf.reshape(mask, [512, 512, 3])
    mask = tf.cast(mask, tf.float32)
    features['mask'] = mask
    return features

dataset_path = glob('content/gdrive/MyDrive/Dataset/*.tfrec')
raw_image_dataset = tf.data.TFRecordDataset(dataset_path)
dataset = raw_image_dataset.map(_parse_image_function)
dataset = dataset.make_one_shot_iterator().get_next()
# Out:
# WARNING:tensorflow:From <ipython-input-11-33f4a627090d>:20: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.

# %%
r = sess.run(dataset)
mask = np.zeros_like(r['mask'])
mask[:,:,1] = 1
mask = cv2.bitwise_and(r['mask'], mask)[:,:,1:2]

# %%
r['image'].shape, mask.shape
# Out:
# ((512, 512, 3), (512, 512, 1))

# %%
from skimage.transform import resize

img_resize = resize(r['image'], (256, 256), anti_aliasing=False)
mask_resize = resize(mask, (256, 256), anti_aliasing=False)

# %%
sess.run(loss, feed_dict = {model.X: [img_resize], model.Y: [mask_resize]})
# Out:
# 1.5774696
