# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
import segmentation_models as sm
import tensorflow as tf
import numpy as np
import utils_tf1
from glob import glob
import cv2
import matplotlib.pyplot as plt
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
BACKBONE = 'efficientnetb2'
BATCH_SIZE = 8
CLASSES = ['paddy']
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)
activation = 'sigmoid' if n_classes == 1 else 'softmax'

class Model:
    def __init__(self, img_size=256):
        self.X = tf.placeholder(tf.float32, (None, img_size, img_size, 3))
        X = tf.identity(self.X, name = 'input')
        model = sm.Unet(BACKBONE, classes=n_classes, activation=activation)
        self.logits = model(X)
        self.logits = tf.identity(self.logits, name = 'logits')

# %%
tf.compat.v1.reset_default_graph()
model = Model()
# Out:
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/util/deprecation.py:507: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
model.logits
# Out:
# <tf.Tensor 'logits:0' shape=(?, 256, 256, 1) dtype=float32>

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
checkpoint_file = 'efficientnetb2-unet-jelapang-padi/model.ckpt-5000'
var_list = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)
assignment_map, initialized_variable_names = utils_tf1.get_assignment_map_from_checkpoint(var_list, 
                                                                                          checkpoint_file)
# Out:
# WARNING:tensorflow:From /home/husein/malaya/projects/malaysia_ai_projects/jelapang_padi/utils_tf1.py:141: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:  name = stem_conv/kernel:0, shape = (3, 3, 3, 32), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = stem_bn/gamma:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = stem_bn/beta:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = stem_bn/moving_mean:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = stem_bn/moving_variance:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_dwconv/depthwise_kernel:0, shape = (3, 3, 32, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_bn/gamma:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_bn/beta:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_bn/moving_mean:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_bn/moving_variance:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_se_reduce/kernel:0, shape = (1, 1, 32, 8), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_se_reduce/bias:0, shape = (8,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_se_expand/kernel:0, shape = (1, 1, 8, 32), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_se_expand/bias:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_project_conv/kernel:0, shape = (1, 1, 32, 16), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_project_bn/gamma:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_project_bn/beta:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_project_bn/moving_mean:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1a_project_bn/moving_variance:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_dwconv/depthwise_kernel:0, shape = (3, 3, 16, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_bn/gamma:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_bn/beta:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_bn/moving_mean:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_bn/moving_variance:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_se_reduce/kernel:0, shape = (1, 1, 16, 4), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_se_reduce/bias:0, shape = (4,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_se_expand/kernel:0, shape = (1, 1, 4, 16), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_se_expand/bias:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_project_conv/kernel:0, shape = (1, 1, 16, 16), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_project_bn/gamma:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_project_bn/beta:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_project_bn/moving_mean:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block1b_project_bn/moving_variance:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_expand_conv/kernel:0, shape = (1, 1, 16, 96), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_expand_bn/gamma:0, shape = (96,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_expand_bn/beta:0, shape = (96,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_expand_bn/moving_mean:0, shape = (96,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_expand_bn/moving_variance:0, shape = (96,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_dwconv/depthwise_kernel:0, shape = (3, 3, 96, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_bn/gamma:0, shape = (96,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_bn/beta:0, shape = (96,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_bn/moving_mean:0, shape = (96,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_bn/moving_variance:0, shape = (96,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_se_reduce/kernel:0, shape = (1, 1, 96, 4), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_se_reduce/bias:0, shape = (4,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_se_expand/kernel:0, shape = (1, 1, 4, 96), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_se_expand/bias:0, shape = (96,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_project_conv/kernel:0, shape = (1, 1, 96, 24), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_project_bn/gamma:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_project_bn/beta:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_project_bn/moving_mean:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2a_project_bn/moving_variance:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_expand_conv/kernel:0, shape = (1, 1, 24, 144), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_expand_bn/gamma:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_expand_bn/beta:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_expand_bn/moving_mean:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_expand_bn/moving_variance:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_dwconv/depthwise_kernel:0, shape = (3, 3, 144, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_bn/gamma:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_bn/beta:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_bn/moving_mean:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_bn/moving_variance:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_se_reduce/kernel:0, shape = (1, 1, 144, 6), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_se_reduce/bias:0, shape = (6,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_se_expand/kernel:0, shape = (1, 1, 6, 144), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_se_expand/bias:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_project_conv/kernel:0, shape = (1, 1, 144, 24), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_project_bn/gamma:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_project_bn/beta:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_project_bn/moving_mean:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2b_project_bn/moving_variance:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_expand_conv/kernel:0, shape = (1, 1, 24, 144), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_expand_bn/gamma:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_expand_bn/beta:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_expand_bn/moving_mean:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_expand_bn/moving_variance:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_dwconv/depthwise_kernel:0, shape = (3, 3, 144, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_bn/gamma:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_bn/beta:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_bn/moving_mean:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_bn/moving_variance:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_se_reduce/kernel:0, shape = (1, 1, 144, 6), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_se_reduce/bias:0, shape = (6,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_se_expand/kernel:0, shape = (1, 1, 6, 144), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_se_expand/bias:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_project_conv/kernel:0, shape = (1, 1, 144, 24), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_project_bn/gamma:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_project_bn/beta:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_project_bn/moving_mean:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block2c_project_bn/moving_variance:0, shape = (24,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_expand_conv/kernel:0, shape = (1, 1, 24, 144), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_expand_bn/gamma:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_expand_bn/beta:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_expand_bn/moving_mean:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_expand_bn/moving_variance:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_dwconv/depthwise_kernel:0, shape = (5, 5, 144, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_bn/gamma:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_bn/beta:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_bn/moving_mean:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_bn/moving_variance:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_se_reduce/kernel:0, shape = (1, 1, 144, 6), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_se_reduce/bias:0, shape = (6,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_se_expand/kernel:0, shape = (1, 1, 6, 144), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_se_expand/bias:0, shape = (144,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_project_conv/kernel:0, shape = (1, 1, 144, 48), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_project_bn/gamma:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_project_bn/beta:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_project_bn/moving_mean:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3a_project_bn/moving_variance:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_expand_conv/kernel:0, shape = (1, 1, 48, 288), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_expand_bn/gamma:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_expand_bn/beta:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_expand_bn/moving_mean:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_expand_bn/moving_variance:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_dwconv/depthwise_kernel:0, shape = (5, 5, 288, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_bn/gamma:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_bn/beta:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_bn/moving_mean:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_bn/moving_variance:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_se_reduce/kernel:0, shape = (1, 1, 288, 12), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_se_reduce/bias:0, shape = (12,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_se_expand/kernel:0, shape = (1, 1, 12, 288), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_se_expand/bias:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_project_conv/kernel:0, shape = (1, 1, 288, 48), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_project_bn/gamma:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_project_bn/beta:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_project_bn/moving_mean:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3b_project_bn/moving_variance:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_expand_conv/kernel:0, shape = (1, 1, 48, 288), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_expand_bn/gamma:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_expand_bn/beta:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_expand_bn/moving_mean:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_expand_bn/moving_variance:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_dwconv/depthwise_kernel:0, shape = (5, 5, 288, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_bn/gamma:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_bn/beta:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_bn/moving_mean:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_bn/moving_variance:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_se_reduce/kernel:0, shape = (1, 1, 288, 12), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_se_reduce/bias:0, shape = (12,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_se_expand/kernel:0, shape = (1, 1, 12, 288), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_se_expand/bias:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_project_conv/kernel:0, shape = (1, 1, 288, 48), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_project_bn/gamma:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_project_bn/beta:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_project_bn/moving_mean:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block3c_project_bn/moving_variance:0, shape = (48,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_expand_conv/kernel:0, shape = (1, 1, 48, 288), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_expand_bn/gamma:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_expand_bn/beta:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_expand_bn/moving_mean:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_expand_bn/moving_variance:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_dwconv/depthwise_kernel:0, shape = (3, 3, 288, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_bn/gamma:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_bn/beta:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_bn/moving_mean:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_bn/moving_variance:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_se_reduce/kernel:0, shape = (1, 1, 288, 12), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_se_reduce/bias:0, shape = (12,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_se_expand/kernel:0, shape = (1, 1, 12, 288), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_se_expand/bias:0, shape = (288,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_project_conv/kernel:0, shape = (1, 1, 288, 88), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_project_bn/gamma:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_project_bn/beta:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_project_bn/moving_mean:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4a_project_bn/moving_variance:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_expand_conv/kernel:0, shape = (1, 1, 88, 528), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_expand_bn/gamma:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_expand_bn/beta:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_expand_bn/moving_mean:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_expand_bn/moving_variance:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_dwconv/depthwise_kernel:0, shape = (3, 3, 528, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_bn/gamma:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_bn/beta:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_bn/moving_mean:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_bn/moving_variance:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_se_reduce/kernel:0, shape = (1, 1, 528, 22), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_se_reduce/bias:0, shape = (22,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_se_expand/kernel:0, shape = (1, 1, 22, 528), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_se_expand/bias:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_project_conv/kernel:0, shape = (1, 1, 528, 88), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_project_bn/gamma:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_project_bn/beta:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_project_bn/moving_mean:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4b_project_bn/moving_variance:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_expand_conv/kernel:0, shape = (1, 1, 88, 528), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_expand_bn/gamma:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_expand_bn/beta:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_expand_bn/moving_mean:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_expand_bn/moving_variance:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_dwconv/depthwise_kernel:0, shape = (3, 3, 528, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_bn/gamma:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_bn/beta:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_bn/moving_mean:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_bn/moving_variance:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_se_reduce/kernel:0, shape = (1, 1, 528, 22), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_se_reduce/bias:0, shape = (22,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_se_expand/kernel:0, shape = (1, 1, 22, 528), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_se_expand/bias:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_project_conv/kernel:0, shape = (1, 1, 528, 88), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_project_bn/gamma:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_project_bn/beta:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_project_bn/moving_mean:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4c_project_bn/moving_variance:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_expand_conv/kernel:0, shape = (1, 1, 88, 528), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_expand_bn/gamma:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_expand_bn/beta:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_expand_bn/moving_mean:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_expand_bn/moving_variance:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_dwconv/depthwise_kernel:0, shape = (3, 3, 528, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_bn/gamma:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_bn/beta:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_bn/moving_mean:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_bn/moving_variance:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_se_reduce/kernel:0, shape = (1, 1, 528, 22), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_se_reduce/bias:0, shape = (22,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_se_expand/kernel:0, shape = (1, 1, 22, 528), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_se_expand/bias:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_project_conv/kernel:0, shape = (1, 1, 528, 88), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_project_bn/gamma:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_project_bn/beta:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_project_bn/moving_mean:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block4d_project_bn/moving_variance:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_expand_conv/kernel:0, shape = (1, 1, 88, 528), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_expand_bn/gamma:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_expand_bn/beta:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_expand_bn/moving_mean:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_expand_bn/moving_variance:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_dwconv/depthwise_kernel:0, shape = (5, 5, 528, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_bn/gamma:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_bn/beta:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_bn/moving_mean:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_bn/moving_variance:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_se_reduce/kernel:0, shape = (1, 1, 528, 22), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_se_reduce/bias:0, shape = (22,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_se_expand/kernel:0, shape = (1, 1, 22, 528), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_se_expand/bias:0, shape = (528,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_project_conv/kernel:0, shape = (1, 1, 528, 120), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_project_bn/gamma:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_project_bn/beta:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_project_bn/moving_mean:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5a_project_bn/moving_variance:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_expand_conv/kernel:0, shape = (1, 1, 120, 720), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_expand_bn/gamma:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_expand_bn/beta:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_expand_bn/moving_mean:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_expand_bn/moving_variance:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_dwconv/depthwise_kernel:0, shape = (5, 5, 720, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_bn/gamma:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_bn/beta:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_bn/moving_mean:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_bn/moving_variance:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_se_reduce/kernel:0, shape = (1, 1, 720, 30), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_se_reduce/bias:0, shape = (30,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_se_expand/kernel:0, shape = (1, 1, 30, 720), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_se_expand/bias:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_project_conv/kernel:0, shape = (1, 1, 720, 120), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_project_bn/gamma:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_project_bn/beta:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_project_bn/moving_mean:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5b_project_bn/moving_variance:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_expand_conv/kernel:0, shape = (1, 1, 120, 720), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_expand_bn/gamma:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_expand_bn/beta:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_expand_bn/moving_mean:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_expand_bn/moving_variance:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_dwconv/depthwise_kernel:0, shape = (5, 5, 720, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_bn/gamma:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_bn/beta:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_bn/moving_mean:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_bn/moving_variance:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_se_reduce/kernel:0, shape = (1, 1, 720, 30), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_se_reduce/bias:0, shape = (30,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_se_expand/kernel:0, shape = (1, 1, 30, 720), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_se_expand/bias:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_project_conv/kernel:0, shape = (1, 1, 720, 120), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_project_bn/gamma:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_project_bn/beta:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_project_bn/moving_mean:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5c_project_bn/moving_variance:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_expand_conv/kernel:0, shape = (1, 1, 120, 720), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_expand_bn/gamma:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_expand_bn/beta:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_expand_bn/moving_mean:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_expand_bn/moving_variance:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_dwconv/depthwise_kernel:0, shape = (5, 5, 720, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_bn/gamma:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_bn/beta:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_bn/moving_mean:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_bn/moving_variance:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_se_reduce/kernel:0, shape = (1, 1, 720, 30), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_se_reduce/bias:0, shape = (30,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_se_expand/kernel:0, shape = (1, 1, 30, 720), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_se_expand/bias:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_project_conv/kernel:0, shape = (1, 1, 720, 120), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_project_bn/gamma:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_project_bn/beta:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_project_bn/moving_mean:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block5d_project_bn/moving_variance:0, shape = (120,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_expand_conv/kernel:0, shape = (1, 1, 120, 720), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_expand_bn/gamma:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_expand_bn/beta:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_expand_bn/moving_mean:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_expand_bn/moving_variance:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_dwconv/depthwise_kernel:0, shape = (5, 5, 720, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_bn/gamma:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_bn/beta:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_bn/moving_mean:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_bn/moving_variance:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_se_reduce/kernel:0, shape = (1, 1, 720, 30), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_se_reduce/bias:0, shape = (30,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_se_expand/kernel:0, shape = (1, 1, 30, 720), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_se_expand/bias:0, shape = (720,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_project_conv/kernel:0, shape = (1, 1, 720, 208), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_project_bn/gamma:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_project_bn/beta:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_project_bn/moving_mean:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6a_project_bn/moving_variance:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_expand_conv/kernel:0, shape = (1, 1, 208, 1248), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_expand_bn/gamma:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_expand_bn/beta:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_expand_bn/moving_mean:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_expand_bn/moving_variance:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_dwconv/depthwise_kernel:0, shape = (5, 5, 1248, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_bn/gamma:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_bn/beta:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_bn/moving_mean:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_bn/moving_variance:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_se_reduce/kernel:0, shape = (1, 1, 1248, 52), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_se_reduce/bias:0, shape = (52,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_se_expand/kernel:0, shape = (1, 1, 52, 1248), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_se_expand/bias:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_project_conv/kernel:0, shape = (1, 1, 1248, 208), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_project_bn/gamma:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_project_bn/beta:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_project_bn/moving_mean:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6b_project_bn/moving_variance:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_expand_conv/kernel:0, shape = (1, 1, 208, 1248), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_expand_bn/gamma:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_expand_bn/beta:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_expand_bn/moving_mean:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_expand_bn/moving_variance:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_dwconv/depthwise_kernel:0, shape = (5, 5, 1248, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_bn/gamma:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_bn/beta:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_bn/moving_mean:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_bn/moving_variance:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_se_reduce/kernel:0, shape = (1, 1, 1248, 52), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_se_reduce/bias:0, shape = (52,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_se_expand/kernel:0, shape = (1, 1, 52, 1248), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_se_expand/bias:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_project_conv/kernel:0, shape = (1, 1, 1248, 208), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_project_bn/gamma:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_project_bn/beta:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_project_bn/moving_mean:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6c_project_bn/moving_variance:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_expand_conv/kernel:0, shape = (1, 1, 208, 1248), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_expand_bn/gamma:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_expand_bn/beta:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_expand_bn/moving_mean:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_expand_bn/moving_variance:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_dwconv/depthwise_kernel:0, shape = (5, 5, 1248, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_bn/gamma:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_bn/beta:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_bn/moving_mean:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_bn/moving_variance:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_se_reduce/kernel:0, shape = (1, 1, 1248, 52), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_se_reduce/bias:0, shape = (52,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_se_expand/kernel:0, shape = (1, 1, 52, 1248), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_se_expand/bias:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_project_conv/kernel:0, shape = (1, 1, 1248, 208), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_project_bn/gamma:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_project_bn/beta:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_project_bn/moving_mean:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6d_project_bn/moving_variance:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_expand_conv/kernel:0, shape = (1, 1, 208, 1248), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_expand_bn/gamma:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_expand_bn/beta:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_expand_bn/moving_mean:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_expand_bn/moving_variance:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_dwconv/depthwise_kernel:0, shape = (5, 5, 1248, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_bn/gamma:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_bn/beta:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_bn/moving_mean:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_bn/moving_variance:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_se_reduce/kernel:0, shape = (1, 1, 1248, 52), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_se_reduce/bias:0, shape = (52,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_se_expand/kernel:0, shape = (1, 1, 52, 1248), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_se_expand/bias:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_project_conv/kernel:0, shape = (1, 1, 1248, 208), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_project_bn/gamma:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_project_bn/beta:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_project_bn/moving_mean:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block6e_project_bn/moving_variance:0, shape = (208,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_expand_conv/kernel:0, shape = (1, 1, 208, 1248), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_expand_bn/gamma:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_expand_bn/beta:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_expand_bn/moving_mean:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_expand_bn/moving_variance:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_dwconv/depthwise_kernel:0, shape = (3, 3, 1248, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_bn/gamma:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_bn/beta:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_bn/moving_mean:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_bn/moving_variance:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_se_reduce/kernel:0, shape = (1, 1, 1248, 52), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_se_reduce/bias:0, shape = (52,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_se_expand/kernel:0, shape = (1, 1, 52, 1248), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_se_expand/bias:0, shape = (1248,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_project_conv/kernel:0, shape = (1, 1, 1248, 352), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_project_bn/gamma:0, shape = (352,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_project_bn/beta:0, shape = (352,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_project_bn/moving_mean:0, shape = (352,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7a_project_bn/moving_variance:0, shape = (352,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_expand_conv/kernel:0, shape = (1, 1, 352, 2112), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_expand_bn/gamma:0, shape = (2112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_expand_bn/beta:0, shape = (2112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_expand_bn/moving_mean:0, shape = (2112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_expand_bn/moving_variance:0, shape = (2112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_dwconv/depthwise_kernel:0, shape = (3, 3, 2112, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_bn/gamma:0, shape = (2112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_bn/beta:0, shape = (2112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_bn/moving_mean:0, shape = (2112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_bn/moving_variance:0, shape = (2112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_se_reduce/kernel:0, shape = (1, 1, 2112, 88), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_se_reduce/bias:0, shape = (88,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_se_expand/kernel:0, shape = (1, 1, 88, 2112), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_se_expand/bias:0, shape = (2112,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_project_conv/kernel:0, shape = (1, 1, 2112, 352), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_project_bn/gamma:0, shape = (352,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_project_bn/beta:0, shape = (352,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_project_bn/moving_mean:0, shape = (352,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = block7b_project_bn/moving_variance:0, shape = (352,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = top_conv/kernel:0, shape = (1, 1, 352, 1408), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = top_bn/gamma:0, shape = (1408,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = top_bn/beta:0, shape = (1408,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = top_bn/moving_mean:0, shape = (1408,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = top_bn/moving_variance:0, shape = (1408,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage0a_conv/kernel:0, shape = (3, 3, 2128, 256), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage0a_bn/gamma:0, shape = (256,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage0a_bn/beta:0, shape = (256,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage0a_bn/moving_mean:0, shape = (256,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage0a_bn/moving_variance:0, shape = (256,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage0b_conv/kernel:0, shape = (3, 3, 256, 256), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage0b_bn/gamma:0, shape = (256,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage0b_bn/beta:0, shape = (256,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage0b_bn/moving_mean:0, shape = (256,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage0b_bn/moving_variance:0, shape = (256,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage1a_conv/kernel:0, shape = (3, 3, 544, 128), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage1a_bn/gamma:0, shape = (128,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage1a_bn/beta:0, shape = (128,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage1a_bn/moving_mean:0, shape = (128,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage1a_bn/moving_variance:0, shape = (128,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage1b_conv/kernel:0, shape = (3, 3, 128, 128), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage1b_bn/gamma:0, shape = (128,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage1b_bn/beta:0, shape = (128,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage1b_bn/moving_mean:0, shape = (128,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage1b_bn/moving_variance:0, shape = (128,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage2a_conv/kernel:0, shape = (3, 3, 272, 64), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage2a_bn/gamma:0, shape = (64,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage2a_bn/beta:0, shape = (64,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage2a_bn/moving_mean:0, shape = (64,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage2a_bn/moving_variance:0, shape = (64,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage2b_conv/kernel:0, shape = (3, 3, 64, 64), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage2b_bn/gamma:0, shape = (64,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage2b_bn/beta:0, shape = (64,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage2b_bn/moving_mean:0, shape = (64,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage2b_bn/moving_variance:0, shape = (64,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage3a_conv/kernel:0, shape = (3, 3, 160, 32), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage3a_bn/gamma:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage3a_bn/beta:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage3a_bn/moving_mean:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage3a_bn/moving_variance:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage3b_conv/kernel:0, shape = (3, 3, 32, 32), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage3b_bn/gamma:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage3b_bn/beta:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage3b_bn/moving_mean:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage3b_bn/moving_variance:0, shape = (32,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage4a_conv/kernel:0, shape = (3, 3, 32, 16), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage4a_bn/gamma:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage4a_bn/beta:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage4a_bn/moving_mean:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage4a_bn/moving_variance:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage4b_conv/kernel:0, shape = (3, 3, 16, 16), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage4b_bn/gamma:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage4b_bn/beta:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage4b_bn/moving_mean:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = decoder_stage4b_bn/moving_variance:0, shape = (16,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = final_conv/kernel:0, shape = (3, 3, 16, 1), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = final_conv/bias:0, shape = (1,), *INIT_FROM_CKPT*

# %%
saver = tf.train.Saver(var_list = assignment_map)
saver.restore(sess, checkpoint_file)
# Out:
# INFO:tensorflow:Restoring parameters from efficientnetb2-unet-jelapang-padi/model.ckpt-5000

# %%
from skimage.io import imread
from skimage.transform import resize

sekinchan = glob('sekinchan/*.png')
kedah = glob('kedah/*.png')

len(sekinchan), len(kedah)
# Out:
# (6335, 3060)

# %%
image = imread(sekinchan[3])
image = resize(image, (256, 256), anti_aliasing=False)
plt.imshow(image)

# %%
def preprocess_input(x):
    x = x.copy()
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    x[..., 0] -= mean[0]
    x[..., 1] -= mean[1]
    x[..., 2] -= mean[2]
    x[..., 0] /= std[0]
    x[..., 1] /= std[1]
    x[..., 2] /= std[2]
    return x

# %%
logits = sess.run(model.logits, feed_dict = {model.X: [preprocess_input(image)]})
logits.shape
# Out:
# (1, 256, 256, 1)

# %%
plt.figure(figsize = (10, 5))
plt.subplot(1,2,1)
plt.imshow(image)
plt.subplot(1,2,2)
plt.imshow(np.around(logits[0,:,:,0]))

# %%
saver = tf.train.Saver()
saver.save(sess, 'b2/model.ckpt')
# Out:
# 'b2/model.ckpt'

# %%
strings = ','.join(
    [
        n.name
        for n in tf.get_default_graph().as_graph_def().node
        if ('Variable' in n.op
        or 'gather' in n.op.lower()
        or n.name == 'input'
        or 'logits' in n.name
        or 'seq_lens' in n.name)
        and 'adam' not in n.name
        and 'global_step' not in n.name
        and 'Assign' not in n.name
        and 'ReadVariableOp' not in n.name
        and 'Gather' not in n.name
    ]
)
strings.split(',')
# Out:
# ['input', 'logits']

# %%
def freeze_graph(model_dir, output_node_names):

    if not tf.gfile.Exists(model_dir):
        raise AssertionError(
            "Export directory doesn't exists. Please specify an export "
            'directory: %s' % model_dir
        )

    checkpoint = tf.train.get_checkpoint_state(model_dir)
    input_checkpoint = checkpoint.model_checkpoint_path

    absolute_model_dir = '/'.join(input_checkpoint.split('/')[:-1])
    output_graph = absolute_model_dir + '/frozen_model.pb'
    clear_devices = True
    with tf.Session(graph = tf.Graph()) as sess:
        saver = tf.train.import_meta_graph(
            input_checkpoint + '.meta', clear_devices = clear_devices
        )
        saver.restore(sess, input_checkpoint)
        output_graph_def = tf.graph_util.convert_variables_to_constants(
            sess,
            tf.get_default_graph().as_graph_def(),
            output_node_names.split(','),
        )
        with tf.gfile.GFile(output_graph, 'wb') as f:
            f.write(output_graph_def.SerializeToString())
        print('%d ops in the final graph.' % len(output_graph_def.node))

# %%
freeze_graph('b2', strings)
# Out:
# INFO:tensorflow:Restoring parameters from b2/model.ckpt
# WARNING:tensorflow:From <ipython-input-16-9a7215a4e58a>:23: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/husein/.local/lib/python3.6/site-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 489 variables.
# INFO:tensorflow:Converted 489 variables to const ops.
# 3609 ops in the final graph.

# %%
def load_graph(frozen_graph_filename):
    with tf.gfile.GFile(frozen_graph_filename, 'rb') as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())
                
    with tf.Graph().as_default() as graph:
        tf.import_graph_def(graph_def)
        
    return graph

# %%
g = load_graph('b2/frozen_model.pb')
X = g.get_tensor_by_name('import/input:0')
logits = g.get_tensor_by_name('import/logits:0')

# %%
test_sess = tf.Session(graph = g)

# %%
r = test_sess.run(logits, feed_dict = {X: [preprocess_input(image)]})
plt.figure(figsize = (10, 5))
plt.subplot(1,2,1)
plt.imshow(image)
plt.subplot(1,2,2)
plt.imshow(np.around(r[0,:,:,0]))

# %%
from tensorflow.tools.graph_transforms import TransformGraph

# %%
transforms = ['add_default_attributes',
             'remove_nodes(op=Identity, op=CheckNumerics, op=Dropout)',
             'fold_batch_norms',
             'fold_old_batch_norms',
             'quantize_weights(fallback_min=-10, fallback_max=10)',
             'strip_unused_nodes',
             'sort_by_execution_order']

pb = 'b2/frozen_model.pb'

input_graph_def = tf.GraphDef()
with tf.gfile.FastGFile(pb, 'rb') as f:
    input_graph_def.ParseFromString(f.read())

transformed_graph_def = TransformGraph(input_graph_def, 
                                           ['input'],
                                           ['logits'], transforms)
    
with tf.gfile.GFile(f'{pb}.quantized', 'wb') as f:
    f.write(transformed_graph_def.SerializeToString())
# Out:
# WARNING:tensorflow:From <ipython-input-23-e356cd659ffb>:12: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.

# %%
# !cp efficientnetb2-unet-jelapang-padi/events.out.tfevents* b2
# !cp efficientnetb2-unet-jelapang-padi/graph.pbtxt b2

# %%
# !mkdir efficientnet-b2
# !cp b2/* efficientnet-b2
# Out:
# mkdir: cannot create directory ‘efficientnet-b2’: File exists
